# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import gmaps.datasets

# Import API key
from api_keys2 import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#Load csv from part 1 into dataframe
output_data = "cities.csv"
df = pd.read_csv(output_data)
df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mareeba -17.0000  145.4333    87.800        66          75
# 1         Albany  42.6001  -73.9662    26.996        59         100
# 2         Atuona  -9.8000 -139.0333    78.260        77          69
# 3       Hermanus -34.4187   19.2345    62.996        93         100
# 4      Saskylakh  71.9167  114.0833   -26.176        84         100
# ..           ...      ...       ...       ...       ...         ...
# 557   Marakkanam  12.2000   79.9500    76.838        87          44
# 558         Umeå  63.8284   20.2597    30.200        69          90
# 559         Luau -10.7073   22.2247    62.312        99          82
# 560       Agadez  19.7500   10.2500    65.354        26           0
# 561  Springfield  37.2153  -93.2982    30.002        74          90
#
#      Wind Speed Country        Date
# 0          3.09      AU  1610243809
# 1          3.44      US  1610243707
# 2          7.02      PF  1610243809
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure gmaps
gmaps.configure(api_key=g_key)

# %%
#Set locations and weight
humidity = df['Humidity'].astype(float)

locations = df[['Lat', 'Lng']]

fig=gmaps.figure()

#Add heatmap layer
heatmap_layer = gmaps.heatmap_layer(locations, weights=humidity,
                                dissipating=False, max_intensity=5,
                                point_radius = 2)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Set ideal weather conditions and find cities matching that criteria, create a new df with ideal cities
ideal_df = df.loc[(df['Max Temp'] < 85) & 
                  (df['Max Temp'] > 75) & 
                  (df['Wind Speed'] < 8) &
                 (df['Cloudiness'] == 0)]
ideal_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 248  Pundaguitan   6.3711  126.1689    82.526        75           0
# 282       Beloha -25.1667   45.0500    76.154        76           0
# 309        Lagos   6.5833    3.7500    77.648        89           0
# 329     Upington -28.4478   21.2561    77.000        65           0
# 494        Morón -34.6534  -58.6198    77.000        69           0
#
#      Wind Speed Country        Date
# 248        2.45      PH  1610243840
# 282        3.00      MG  1610243844
# 309        1.95      NG  1610243462
# 329        5.14      ZA  1610243850
# 494        0.45      AR  1610243873

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = pd.DataFrame(ideal_df, columns=["City", "Country", "Lat", "Lng"])
hotel_df["Hotel Name"] = " "
hotel_df
# Out:
#             City Country      Lat       Lng Hotel Name
# 248  Pundaguitan      PH   6.3711  126.1689
# 282       Beloha      MG -25.1667   45.0500
# 309        Lagos      NG   6.5833    3.7500
# 329     Upington      ZA -28.4478   21.2561
# 494        Morón      AR -34.6534  -58.6198

# %%
#Set url and make API call
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

hotel_name = []

radius = 5000
param = {
    "radius": radius,
    "type": "lodging",
    "keyword": "hotel",
    "key":g_key}

for index, row in hotel_df.iterrows():
    h_lat = row["Lat"]
    h_lng = row["Lng"]
    param['location'] = f"{h_lat}, {h_lng}"
    hotel_response = requests.get(url, params=param).json()
    
    try:
        hotel_name.append(hotel_response['results'][0]['name'])
    except: 
        hotel_name.append(np.nan)
hotel_name
# Out:
# ['El Don Resort', nan, nan, 'Allianto Boutique Hotel & Spa', 'Hotel Cabildo']

# %%
#Merge hotel names into hotel_df, drop nan values
hotel_df['Hotel Name'] = hotel_name
new_hotel_df = hotel_df.dropna()
new_hotel_df
# Out:
#             City Country      Lat       Lng                     Hotel Name
# 248  Pundaguitan      PH   6.3711  126.1689                  El Don Resort
# 329     Upington      ZA -28.4478   21.2561  Allianto Boutique Hotel & Spa
# 494        Morón      AR -34.6534  -58.6198                  Hotel Cabildo

# %%
#Export new df to csv
new_hotel_df.to_csv('hotel_export.csv')

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in new_hotel_df.iterrows()]
locations2 = new_hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations2, info_box_content=hotel_info)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
