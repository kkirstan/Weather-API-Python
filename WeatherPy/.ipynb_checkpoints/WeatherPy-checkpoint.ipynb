# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# Perform API Calls

# %%
#Make a request for each of the cities
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&q="

import json

responses = []

for x in range(len(cities)):
    print(f"Processing Record {x} of Set 1 | {cities[x]}")
    
    response = requests.get(query_url + cities[x])
    responses.append(response.json())
# Out:
# Processing Record 0 of Set 1 | mataura
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | cap malheureux
# Processing Record 7 of Set 1 | gelgaudiskis
# Processing Record 8 of Set 1 | hithadhoo
# Processing Record 9 of Set 1 | rusape
# Processing Record 10 of Set 1 | sabha
# Processing Record 11 of Set 1 | aklavik
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | nguiu
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | samusu
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | copiapo
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | saint anthony
# Processing Record 22 of Set 1 | padang
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | moengo
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | axim
# Processing Record 27 of Set 1 | ancud
# Processing Record 28 of Set 1 | gimbi
# Processing Record 29 of Set 1 | tual
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | riyadh
# Processing Record 32 of Set 1 | dandong
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | sechura
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | zelenoborsk
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | utevka
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | manokwari
# Processing Record 41 of Set 1 | vilhena
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | karratha
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | hof
# Processing Record 46 of Set 1 | sentyabrskiy
# Processing Record 47 of Set 1 | fortuna
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 50 of Set 1 | batemans bay
# Processing Record 51 of Set 1 | jumilla
# Processing Record 52 of Set 1 | kaitangata
# Processing Record 53 of Set 1 | lagoa
# Processing Record 54 of Set 1 | gold coast
# Processing Record 55 of Set 1 | oblivskaya
# Processing Record 56 of Set 1 | tambopata
# Processing Record 57 of Set 1 | crib point
# Processing Record 58 of Set 1 | paptalaya
# Processing Record 59 of Set 1 | kachug
# Processing Record 60 of Set 1 | isabela
# Processing Record 61 of Set 1 | grand-santi
# Processing Record 62 of Set 1 | mayumba
# Processing Record 63 of Set 1 | dwarka
# Processing Record 64 of Set 1 | nizhneyansk
# Processing Record 65 of Set 1 | ribeira grande
# Processing Record 66 of Set 1 | topolobampo
# Processing Record 67 of Set 1 | port alfred
# Processing Record 68 of Set 1 | bilma
# Processing Record 69 of Set 1 | oktyabrskiy
# Processing Record 70 of Set 1 | naze
# Processing Record 71 of Set 1 | cayenne
# Processing Record 72 of Set 1 | lorengau
# Processing Record 73 of Set 1 | chuy
# Processing Record 74 of Set 1 | srednekolymsk
# Processing Record 75 of Set 1 | rawson
# Processing Record 76 of Set 1 | vaini
# Processing Record 77 of Set 1 | king city
# Processing Record 78 of Set 1 | muroto
# Processing Record 79 of Set 1 | zhaotong
# Processing Record 80 of Set 1 | kirakira
# Processing Record 81 of Set 1 | college
# Processing Record 82 of Set 1 | basco
# Processing Record 83 of Set 1 | churapcha
# Processing Record 84 of Set 1 | rockland
# Processing Record 85 of Set 1 | omboue
# Processing Record 86 of Set 1 | amderma
# Processing Record 87 of Set 1 | coruripe
# Processing Record 88 of Set 1 | buk
# Processing Record 89 of Set 1 | isangel
# Processing Record 90 of Set 1 | lavrentiya
# Processing Record 91 of Set 1 | belushya guba
# Processing Record 92 of Set 1 | saldanha
# Processing Record 93 of Set 1 | la ronge
# Processing Record 94 of Set 1 | sredec
# Processing Record 95 of Set 1 | kapaa
# Processing Record 96 of Set 1 | souillac
# Processing Record 97 of Set 1 | tabou
# Processing Record 98 of Set 1 | tasiilaq
# Processing Record 99 of Set 1 | half moon bay
# Processing Record 100 of Set 1 | zorritos
# Processing Record 172 of Set 1 | tuktoyaktuk
# Processing Record 173 of Set 1 | yulara
# Processing Record 174 of Set 1 | myitkyina
# Processing Record 175 of Set 1 | saint-pierre
# Processing Record 176 of Set 1 | port elizabeth
# Processing Record 177 of Set 1 | codrington
# Processing Record 178 of Set 1 | aracaju
# Processing Record 179 of Set 1 | sitka
# Processing Record 180 of Set 1 | nizwa
# Processing Record 181 of Set 1 | yerofey pavlovich
# Processing Record 182 of Set 1 | arraial do cabo
# Processing Record 183 of Set 1 | high prairie
# Processing Record 184 of Set 1 | severo-kurilsk
# Processing Record 185 of Set 1 | te anau
# Processing Record 186 of Set 1 | katsuura
# Processing Record 187 of Set 1 | eyl
# Processing Record 188 of Set 1 | tessalit
# Processing Record 189 of Set 1 | dargaville
# Processing Record 190 of Set 1 | karauzyak
# Processing Record 191 of Set 1 | general teran
# Processing Record 192 of Set 1 | rathdrum
# Processing Record 193 of Set 1 | mar del plata
# Processing Record 194 of Set 1 | margate
# Processing Record 195 of Set 1 | lazaro cardenas
# Processing Record 196 of Set 1 | teguldet
# Processing Record 197 of Set 1 | benguela
# Processing Record 198 of Set 1 | portland
# Processing Record 199 of Set 1 | mackay
# Processing Record 200 of Set 1 | ekhabi
# Processing Record 201 of Set 1 | karpogory
# Processing Record 202 of Set 1 | santo antonio do ica
# Processing Record 203 of Set 1 | illoqqortoormiut
# Processing Record 204 of Set 1 | broome
# Processing Record 205 of Set 1 | torbay
# Processing Record 206 of Set 1 | nikolskoye
# Processing Record 207 of Set 1 | smirnykh
# Processing Record 208 of Set 1 | sulangan
# Processing Record 209 of Set 1 | ternate
# Processing Record 210 of Set 1 | salalah
# Processing Record 211 of Set 1 | schwabmunchen
# Processing Record 212 of Set 1 | barentsburg
# Processing Record 213 of Set 1 | khandbari
# Processing Record 214 of Set 1 | richards bay
# Processing Record 215 of Set 1 | okandja
# Processing Record 216 of Set 1 | teeli
# Processing Record 217 of Set 1 | kungurtug
# Processing Record 218 of Set 1 | kloulklubed
# Processing Record 219 of Set 1 | sotouboua
# Processing Record 220 of Set 1 | saint-philippe
# Processing Record 221 of Set 1 | simpang
# Processing Record 222 of Set 1 | kahului
# Processing Record 223 of Set 1 | korla
# Processing Record 224 of Set 1 | esperance
# Processing Record 225 of Set 1 | eldikan
# Processing Record 226 of Set 1 | sayyan
# Processing Record 227 of Set 1 | ponta do sol
# Processing Record 228 of Set 1 | cockburn town
# Processing Record 229 of Set 1 | tiksi
# Processing Record 230 of Set 1 | sao joao batista
# Processing Record 231 of Set 1 | faanui
# Processing Record 232 of Set 1 | kishi
# Processing Record 233 of Set 1 | pemangkat
# Processing Record 234 of Set 1 | daytona beach
# Processing Record 235 of Set 1 | pisco
# Processing Record 236 of Set 1 | provideniya
# Processing Record 237 of Set 1 | avarua
# Processing Record 238 of Set 1 | brae
# Processing Record 239 of Set 1 | miyazu
# Processing Record 240 of Set 1 | cidreira
# Processing Record 241 of Set 1 | yunjinghong
# Processing Record 454 of Set 1 | tazmalt
# Processing Record 455 of Set 1 | sorland
# Processing Record 456 of Set 1 | coos bay
# Processing Record 457 of Set 1 | artyk
# Processing Record 458 of Set 1 | egvekinot
# Processing Record 459 of Set 1 | pevek
# Processing Record 460 of Set 1 | verkhoyansk
# Processing Record 461 of Set 1 | suntar
# Processing Record 462 of Set 1 | pangody
# Processing Record 463 of Set 1 | druzhba
# Processing Record 464 of Set 1 | makarov
# Processing Record 465 of Set 1 | salima
# Processing Record 466 of Set 1 | kolpny
# Processing Record 467 of Set 1 | laizhou
# Processing Record 468 of Set 1 | taltal
# Processing Record 469 of Set 1 | meyungs
# Processing Record 470 of Set 1 | akureyri
# Processing Record 471 of Set 1 | karachi
# Processing Record 472 of Set 1 | ferkessedougou
# Processing Record 473 of Set 1 | oranjemund
# Processing Record 474 of Set 1 | pudozh
# Processing Record 475 of Set 1 | harper
# Processing Record 476 of Set 1 | waipawa
# Processing Record 477 of Set 1 | takaka
# Processing Record 478 of Set 1 | comodoro rivadavia
# Processing Record 479 of Set 1 | tukrah
# Processing Record 480 of Set 1 | north bend
# Processing Record 481 of Set 1 | bacolod
# Processing Record 482 of Set 1 | warangal
# Processing Record 483 of Set 1 | presidencia roque saenz pena
# Processing Record 484 of Set 1 | labutta
# Processing Record 485 of Set 1 | sobolevo
# Processing Record 486 of Set 1 | belyy yar
# Processing Record 487 of Set 1 | catungan
# Processing Record 488 of Set 1 | biak
# Processing Record 489 of Set 1 | meulaboh
# Processing Record 490 of Set 1 | zhigansk
# Processing Record 491 of Set 1 | ha tinh
# Processing Record 492 of Set 1 | fairbanks
# Processing Record 493 of Set 1 | gambela
# Processing Record 494 of Set 1 | jiddah
# Processing Record 495 of Set 1 | rio gallegos
# Processing Record 496 of Set 1 | alotau
# Processing Record 497 of Set 1 | hailar
# Processing Record 498 of Set 1 | bandarbeyla
# Processing Record 499 of Set 1 | redcliffe
# Processing Record 500 of Set 1 | kargil
# Processing Record 501 of Set 1 | mahon
# Processing Record 502 of Set 1 | avera
# Processing Record 503 of Set 1 | channel-port aux basques
# Processing Record 504 of Set 1 | hidalgo
# Processing Record 505 of Set 1 | irbil
# Processing Record 506 of Set 1 | leh
# Processing Record 507 of Set 1 | kamenskoye
# Processing Record 508 of Set 1 | a coruna
# Processing Record 509 of Set 1 | benton harbor
# Processing Record 510 of Set 1 | rabaul
# Processing Record 511 of Set 1 | ushibuka
# Processing Record 512 of Set 1 | vestmannaeyjar
# Processing Record 513 of Set 1 | jalu
# Processing Record 514 of Set 1 | bibiani
# Processing Record 515 of Set 1 | kansanshi
# Processing Record 516 of Set 1 | saint-augustin
# Processing Record 517 of Set 1 | kamina
# Processing Record 518 of Set 1 | aflu
# Processing Record 519 of Set 1 | casma
# Processing Record 520 of Set 1 | salta
# Processing Record 521 of Set 1 | tripoli
# Processing Record 522 of Set 1 | henties bay
# Processing Record 523 of Set 1 | fare
# Processing Record 593 of Set 1 | moerai
# Processing Record 594 of Set 1 | phan thiet
# Processing Record 595 of Set 1 | abha
# Processing Record 596 of Set 1 | gobabis
# Processing Record 597 of Set 1 | blonduos
# Processing Record 598 of Set 1 | atar
# Processing Record 599 of Set 1 | skibbereen
# Processing Record 600 of Set 1 | lindi
# Processing Record 601 of Set 1 | chimbote
# Processing Record 602 of Set 1 | cape elizabeth
# Processing Record 603 of Set 1 | sarab
# Processing Record 604 of Set 1 | san marcos
# Processing Record 605 of Set 1 | chagda
# Processing Record 606 of Set 1 | buluang
# Processing Record 607 of Set 1 | adrar

# %%
#Extract city weather data from responses list
max_temps = []
cities2 = []
lat = []
lon = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

for city in responses:
    try:
        cities2.append(city['name'])
        max_temps.append(city['main']['temp_max'])
        lat.append(city['coord']['lat'])
        lon.append(city['coord']['lon'])
        humidity.append(city['main']['humidity'])
        cloudiness.append(city['clouds']['all'])
        wind_speed.append(city['wind']['speed'])
        country.append(city['sys']['country'])
        date.append(city['dt'])
    except: 
        continue

# %%
#Change max_temps to farenheit
temps_f = []
for i in max_temps:
    f = ((i - 273.15) * (9/5)) + (32)
    temps_f.append(f)

# %%
#Create new dataframe with extracted data
cities_df = pd.DataFrame({
    "City": cities2,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temps_f,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})

# %%
#Save df as csv
cities_df.to_csv(output_data_file, index=False)

#Display df
cities_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Mataura -46.1927  168.8643    53.996        71          80
# 1           Butaritari   3.0707  172.7902    80.834        82          49
# 2         Punta Arenas -53.1500  -70.9167    53.600        54          75
# 3               Atuona  -9.8000 -139.0333    77.576        80          58
# 4    Saint Paul Harbor  57.7900 -152.4072    39.200        93          90
# ..                 ...      ...       ...       ...       ...         ...
# 554           Chimbote  -9.0853  -78.5783    75.056        71          42
# 555              Sarab  38.6066   44.9883    30.578        86           9
# 556         San Marcos  33.1434 -117.1661    59.000        30           1
# 557            Buluang  13.3068  123.3425    73.760        86         100
# 558              Adrar  20.5022  -10.0711    66.956        26          76
#
#      Wind Speed Country        Date
# 0          4.02      NZ  1610297067
# 1          7.39      KI  1610297067
# 2          9.26      CL  1610297067
# 3          8.17      PF  1610297067
# 4          7.72      US  1610297067
# ..          ...     ...         ...
# 554        4.94      PE  1610296919
# 555        0.29      IR  1610297137
# 556        2.00      US  1610296884
# 557        4.62      PH  1610297137
# 558        7.80      MR  1610297137
#
# [559 rows x 9 columns]

# %%
cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  559.000000  559.000000  559.000000  559.000000  559.000000  559.000000
# mean    20.299613   19.903109   49.385649   71.579606   53.509839    3.728265
# std     33.330052   91.270242   33.847764   21.522690   38.762019    2.547253
# min    -54.800000 -179.166700  -41.368000    9.000000    0.000000    0.060000
# 25%     -7.171500  -59.525000   26.582000   62.000000   13.000000    1.930000
# 50%     23.450000   22.975800   60.098000   78.000000   60.000000    3.170000
# 75%     48.787500   98.357500   77.675000   86.000000   90.000000    5.040000
# max     78.218600  179.316700  100.850000  100.000000  100.000000   12.860000
#
#                Date
# count  5.590000e+02
# mean   1.610297e+09
# std    7.306629e+01
# min    1.610296e+09
# 25%    1.610297e+09
# 50%    1.610297e+09
# 75%    1.610297e+09
# max    1.610297e+09

# %%
#Inspect data to see if any cities have humidity > 100%. 
humidity_error = cities_df.loc[cities_df['Humidity'] > 100]
humidity_error
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#Get the indices of cities that have humidity over 100%
humidity_error.index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# Latitude vs. Temperature Plot

# %%
plot = cities_df.plot(kind="scatter", x="Lat", xlabel="Latitude", y="Max Temp", grid=True, figsize=(8,8), 
               title="City Latitude vs. Max Temperature (04/01/20)")
plot.set_xlabel('Latitude')
plot.set_ylabel('Max Temperature (F)')
plot.xaxis.get_label().set_visible(True)
plt.show()

# %% [markdown]
# Latitude vs. Humidity Plot

# %%
plot = cities_df.plot(kind="scatter", x="Lat", xlabel="Latitude", y="Humidity", grid=True, figsize=(8,8), 
               title="City Latitude vs. Humidity (04/01/20)")
plot.set_xlabel('Latitude')
plot.set_ylabel('Humidity (%)')
plot.xaxis.get_label().set_visible(True)
plt.show()

# %% [markdown]
# Latitude vs. Cloudiness Plot

# %%
plot = cities_df.plot(kind="scatter", x="Lat", xlabel="Latitude", y="Cloudiness", grid=True, figsize=(8,8), 
               title="City Latitude vs. Cloudiness (04/01/20)")
plot.set_xlabel('Latitude')
plot.set_ylabel('Cloudiness (%)')
plot.xaxis.get_label().set_visible(True)
plt.show()

# %% [markdown]
# Latitude vs. Wind Speed Plot

# %%
plot = cities_df.plot(kind="scatter", x="Lat", xlabel="Latitude", y="Wind Speed", grid=True, figsize=(8,8), 
               title="City Latitude vs. Wind Speed (04/01/20)")
plot.set_xlabel('Latitude')
plot.set_ylabel('Wind Speed (mph)')
plot.xaxis.get_label().set_visible(True)
plt.show()

# %% [markdown]
# Linear Regression

# %%
#Create dataframes for northern and southern hemisphere
nh = cities_df.loc[cities_df['Lat'] > 0]
sh = cities_df.loc[cities_df['Lat'] < 0]

# %% [markdown]
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = nh['Lat']
y_values = nh['Max Temp']
tvl_slope, tvl_int, tvl_r, tvl_p, tvl_std_err = linregress(x_values,y_values)
tvl_fit = tvl_slope * x_values + tvl_int
line_eq = "y = " + str(round(tvl_slope,2)) + "x + " + str(round(tvl_int,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,tvl_fit, "r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(line_eq)
print(f" The r-value is: {tvl_r}")
print(f"The r-squared is: {tvl_r**2}")
# Out:
# y = -1.49x + 95.72
#  The r-value is: -0.8658747351258071
# The r-squared is: 0.7497390569291867

# %% [markdown]
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = sh['Lat']
y_values = sh['Max Temp']
tvl1_slope, tvl1_int, tvl1_r, tvl1_p, tvl1_std_err = linregress(x_values,y_values)
tvl1_fit = tvl1_slope * x_values + tvl1_int
line_eq = "y = " + str(round(tvl1_slope,2)) + "x + " + str(round(tvl1_int,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,tvl1_fit, "r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(line_eq)
print(f" The r-value is: {tvl1_r}")
print(f"The r-squared is: {tvl1_r**2}")
# Out:
# y = 0.46x + 84.88
#  The r-value is: 0.5836196808246152
# The r-squared is: 0.3406119318458258

# %% [markdown]
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = nh['Lat']
y_values = nh['Humidity']
hvl_slope, hvl_int, hvl_r, hvl_p, hvl_std_err = linregress(x_values,y_values)
hvl_fit = hvl_slope * x_values + hvl_int
line_eq = "y = " + str(round(hvl_slope,2)) + "x + " + str(round(hvl_int,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,hvl_fit, "r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(line_eq)
print(f" The r-value is: {hvl_r}")
print(f"The r-squared is: {hvl_r**2}")
# Out:
# y = 0.52x + 51.33
#  The r-value is: 0.4524336392122846
# The r-squared is: 0.20469619789087168

# %% [markdown]
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = sh['Lat']
y_values = sh['Humidity']
hvls_slope, hvls_int, hvls_r, hvls_p, hvls_std_err = linregress(x_values,y_values)
hvls_fit = hvls_slope * x_values + hvls_int
line_eq = "y = " + str(round(hvls_slope,2)) + "x + " + str(round(hvls_int,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,hvls_fit, "r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(line_eq)
print(f" The r-value is: {hvls_r}")
print(f"The r-squared is: {hvls_r**2}")
# Out:
# y = 0.22x + 76.12
#  The r-value is: 0.16458878448027023
# The r-squared is: 0.027089467976692844

# %% [markdown]
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = nh['Lat']
y_values = nh['Cloudiness']
cvl_slope, cvl_int, cvl_r, cvl_p, cvl_std_err = linregress(x_values,y_values)
cvl_fit = cvl_slope * x_values + cvl_int
line_eq = "y = " + str(round(cvl_slope,2)) + "x + " + str(round(cvl_int,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,cvl_fit, "r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(line_eq)
print(f" The r-value is: {cvl_r}")
print(f"The r-squared is: {cvl_r**2}")
# Out:
# y = 0.47x + 32.76
#  The r-value is: 0.2341861908997512
# The r-squared is: 0.05484317200813472

# %% [markdown]
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = sh['Lat']
y_values = sh['Cloudiness']
cvls_slope, cvls_int, cvls_r, cvls_p, cvls_std_err = linregress(x_values,y_values)
cvls_fit = cvls_slope * x_values + cvls_int
line_eq = "y = " + str(round(cvls_slope,2)) + "x + " + str(round(cvls_int,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,cvls_fit, "r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(line_eq)
print(f" The r-value is: {cvls_r}")
print(f"The r-squared is: {cvls_r**2}")
# Out:
# y = 0.43x + 67.62
#  The r-value is: 0.16702630038937397
# The r-squared is: 0.027897785021761386

# %% [markdown]
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = nh['Lat']
y_values = nh['Wind Speed']
wvl_slope, wvl_int, wvl_r, wvl_p, wvl_std_err = linregress(x_values,y_values)
wvl_fit = wvl_slope * x_values + wvl_int
line_eq = "y = " + str(round(wvl_slope,2)) + "x + " + str(round(wvl_int,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,wvl_fit, "r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(line_eq)
print(f" The r-value is: {wvl_r}")
print(f"The r-squared is: {wvl_r**2}")
# Out:
# y = -0.0x + 3.77
#  The r-value is: -0.025690427658487294
# The r-squared is: 0.0006599980732759689

# %% [markdown]
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = sh['Lat']
y_values = sh['Wind Speed']
wvls_slope, wvls_int, wvls_r, wvls_p, wvls_std_err = linregress(x_values,y_values)
wvls_fit = wvls_slope * x_values + wvls_int
line_eq = "y = " + str(round(wvls_slope,2)) + "x + " + str(round(wvls_int,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,wvls_fit, "r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(line_eq)
print(f" The r-value is: {wvls_r}")
print(f"The r-squared is: {wvls_r**2}")
# Out:
# y = -0.05x + 2.81
#  The r-value is: -0.27929281943166734
# The r-squared is: 0.07800447898608993
