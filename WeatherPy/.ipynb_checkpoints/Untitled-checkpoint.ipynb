# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %%
#Make a request for each of the cities
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&q="

import json

responses = []

for x in range(len(cities)):
    print(f"Processing Record {x} of Set 1 | {cities[x]}")
    
    response = requests.get(query_url + cities[x])
    responses.append(response.json())
# Out:
# Processing Record 0 of Set 1 | kapaa
# Processing Record 1 of Set 1 | trelew
# Processing Record 2 of Set 1 | sao joao da barra
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | panguna
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | ponta delgada
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | nuevitas
# Processing Record 13 of Set 1 | tshela
# Processing Record 14 of Set 1 | aurillac
# Processing Record 15 of Set 1 | meulaboh
# Processing Record 16 of Set 1 | san jose
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | bubaque
# Processing Record 19 of Set 1 | nioro
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | gunjur
# Processing Record 22 of Set 1 | meyungs
# ...

# %%
#Save output as json file
with open('output_data/responses.json', 'w') as json_file:
    json = json.dump(responses, json_file)

# %%
df = pd.read_json('output_data/responses.json')

# %%
#Convert json to csv
converter = pd.read_json('responses.json')
converter.to_csv(output_data_file, index=False)

# %%
cities_data = pd.read_csv(output_data_file)

# %%
max_temps = []
cities2 = []


for city in responses:
    response2 = requests.get(query_url).json()
    cities2.append(response2['name'])
    max_temps.append(response2['main']['temp_max'])

# %%
print(cities2)

# %%
for city in range(len(cities)):
    temp_dict.append(response['main']['temp_max'])
temp_dict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-328-75fd906544a0> in <module>
#       1 for city in range(len(cities)):
# ----> 2     temp_dict.append(response['main']['temp_max'])
#       3 temp_dict
#
# AttributeError: 'float' object has no attribute 'append'

# %%
cities_df = pd.DataFrame({
    "Max Temp": temp_dict
})

data2 = pd.DataFrame(weather_dict)

# %%
df = pd.DataFrame({
    city = response_json['sys']['name']
    lat = response_json['coord']['lat']
    lng = response_json['coord']['lon']
    max_temp = response_json['main']['temp_max']
    humidity = response_json['main']['humidity']
    cloudiness = response_json['clouds']['all']
    wind_speed = response_json['wind']['speed']
    country = response_json['sys']['country']
    date = response_json['dt']
})
